# %% [markdown]
# ## Import necessary packages

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# ## Import the datasets

# %%
products = pd.read_csv("./products.csv")
products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
order_prior=pd.read_csv("./order_products__prior.csv")
order_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
aisle=pd.read_csv("./aisles.csv")
aisle
# Out:
#      aisle_id                       aisle
# 0           1       prepared soups salads
# 1           2           specialty cheeses
# 2           3         energy granola bars
# 3           4               instant foods
# 4           5  marinades meat preparation
# ..        ...                         ...
# 129       130    hot cereal pancake mixes
# 130       131                   dry pasta
# 131       132                      beauty
# 132       133  muscles joints pain relief
# 133       134  specialty wines champagnes
#
# [134 rows x 2 columns]

# %% [markdown]
# ## Merge the Datasets

# %%
merge=pd.merge(products, order_prior, on="product_id")
merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  order_id  \
# 0           1  Chocolate Sandwich Cookies        61             19      1107
# 1           1  Chocolate Sandwich Cookies        61             19      5319
# 2           1  Chocolate Sandwich Cookies        61             19      7540
# 3           1  Chocolate Sandwich Cookies        61             19      9228
# 4           1  Chocolate Sandwich Cookies        61             19      9273
#
#    add_to_cart_order  reordered
# 0                  7          0
# 1                  3          1
# 2                  4          1
# 3                  2          0
# 4                 30          0

# %%
merge=merge.groupby("aisle_id").size().reset_index(name="aisle_count")
merge
# Out:
#      aisle_id  aisle_count
# 0           1        71928
# 1           2        82491
# 2           3       456386
# 3           4       200687
# 4           5        62510
# ..        ...          ...
# 129       130       158164
# 130       131       266637
# 131       132         6168
# 132       133        18683
# 133       134        11198
#
# [134 rows x 2 columns]

# %%
merge=merge.merge(dept[["aisle_id","aisle"]], on="aisle_id")
merge
# Out:
#      aisle_id  aisle_count                       aisle
# 0           1        71928       prepared soups salads
# 1           2        82491           specialty cheeses
# 2           3       456386         energy granola bars
# 3           4       200687               instant foods
# 4           5        62510  marinades meat preparation
# ..        ...          ...                         ...
# 129       130       158164    hot cereal pancake mixes
# 130       131       266637                   dry pasta
# 131       132         6168                      beauty
# 132       133        18683  muscles joints pain relief
# 133       134        11198  specialty wines champagnes
#
# [134 rows x 3 columns]

# %%
bins = [0, merge["dep_count"].quantile(0.25), merge["aisle_count"].quantile(0.75), max(merge["aisle_count"])]
names = ["low","medium","high"]

merge['Aisle_consumption'] = pd.cut(merge['aisle_count'], bins, labels=names)
merge
# Out:
#     department_id  dep_count       department Department_consumption
# 0               1    2236432           frozen                   high
# 1               2      36291            other                    low
# 2               3    1176787           bakery                 medium
# 3               4    9479291          produce                   high
# 4               5     153696          alcohol                    low
# 5               6     269253    international                    low
# 6               7    2690129        beverages                   high
# 7               8      97724             pets                    low
# 8               9     866627  dry goods pasta                 medium
# 9              10      34573             bulk                    low
# 10             11     447123    personal care                 medium
# 11             12     708931     meat seafood                 medium
# 12             13    1875577           pantry                 medium
# ...

# %%
merge.to_csv("./dep_consumption.csv", index=False)
