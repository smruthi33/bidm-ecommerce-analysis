# %%
import pandas as pd

# %%
orders = pd.read_csv("./orders.csv")
orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
products=pd.read_csv("./products.csv")
products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
products
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49683       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49684       49685                 En Croute Roast Hazelnut Cranberry
# 49685       49686                                   Artisan Baguette
# 49686       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49687       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id
# 0            61             19
# 1           104             13
# 2            94              7
# 3            38              1
# 4             5             13
# ...         ...            ...
# 49683       124              5
# 49684        42              1
# 49685       112              3
# 49686        41              8
# 49687        73             11
#
# [49688 rows x 4 columns]

# %%
aisle = pd.read_csv("./aisles.csv")
dept=pd.read_csv("./departments.csv")

# %%
prod_final=products.merge(aisle, on="aisle_id")

# %%
prod_final
# Out:
#        product_id                                     product_name  aisle_id  \
# 0               1                       Chocolate Sandwich Cookies        61
# 1              78                Nutter Butter Cookie Bites Go-Pak        61
# 2             102                            Danish Butter Cookies        61
# 3             172   Gluten Free All Natural Chocolate Chip Cookies        61
# 4             285                     Mini Nilla Wafers Munch Pack        61
# ...           ...                                              ...       ...
# 49683       47769                    Peas and Potatoe Roti Paratha        76
# 49684       48292  Punjabi Chhole Chickpeas with Potatoes & Onions        76
# 49685       48480                                  Punjab Eggplant        76
# 49686       48830                 Pav Bhaji Mashed Vegetable Curry        76
# 49687       49278                     Channa Masala Chickpea Curry        76
#
#        department_id          aisle
# 0                 19  cookies cakes
# 1                 19  cookies cakes
# 2                 19  cookies cakes
# 3                 19  cookies cakes
# 4                 19  cookies cakes
# ...              ...            ...
# 49683              6   indian foods
# 49684              6   indian foods
# 49685              6   indian foods
# 49686              6   indian foods
# 49687              6   indian foods
#
# [49688 rows x 5 columns]

# %%
del prod_final["aisle_id"]

# %%
prod_final=prod_final.merge(dept, on="department_id")
del prod_final["department_id"]
prod_final.head()
# Out:
#    product_id                                    product_name          aisle  \
# 0           1                      Chocolate Sandwich Cookies  cookies cakes
# 1          78               Nutter Butter Cookie Bites Go-Pak  cookies cakes
# 2         102                           Danish Butter Cookies  cookies cakes
# 3         172  Gluten Free All Natural Chocolate Chip Cookies  cookies cakes
# 4         285                    Mini Nilla Wafers Munch Pack  cookies cakes
#
#   department
# 0     snacks
# 1     snacks
# 2     snacks
# 3     snacks
# 4     snacks

# %%
prod_final
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1              78                  Nutter Butter Cookie Bites Go-Pak
# 2             102                              Danish Butter Cookies
# 3             172     Gluten Free All Natural Chocolate Chip Cookies
# 4             285                       Mini Nilla Wafers Munch Pack
# ...           ...                                                ...
# 49683       22827                         Organic Black Mission Figs
# 49684       28655                         Crystallized Ginger Chunks
# 49685       30365                                    Vegetable Chips
# 49686       38007                     Naturally Sweet Plantain Chips
# 49687       48778  Fit Super A Juice, Cold Pressed, Carrot/Apple/...
#
#                               aisle department
# 0                     cookies cakes     snacks
# 1                     cookies cakes     snacks
# 2                     cookies cakes     snacks
# 3                     cookies cakes     snacks
# 4                     cookies cakes     snacks
# ...                             ...        ...
# 49683  bulk dried fruits vegetables       bulk
# 49684  bulk dried fruits vegetables       bulk
# 49685  bulk dried fruits vegetables       bulk
# 49686  bulk dried fruits vegetables       bulk
# 49687  bulk dried fruits vegetables       bulk
#
# [49688 rows x 4 columns]

# %%
order_prior=pd.read_csv("order_products__prior.csv")
#order_train=pd.read_csv("order_products__train.csv")
order_prior
# Out:
#           order_id  product_id  add_to_cart_order  reordered
# 0                2       33120                  1          1
# 1                2       28985                  2          1
# 2                2        9327                  3          0
# 3                2       45918                  4          1
# 4                2       30035                  5          0
# ...            ...         ...                ...        ...
# 32434484   3421083       39678                  6          1
# 32434485   3421083       11352                  7          0
# 32434486   3421083        4600                  8          0
# 32434487   3421083       24852                  9          1
# 32434488   3421083        5020                 10          1
#
# [32434489 rows x 4 columns]

# %%
order_list=order_prior.merge(prod_final, on="product_id", how="left")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-e86f06481ed4> in <module>
# ----> 1 order_list=order_main_prior.merge(prod_final, on="product_id", how="left")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7282         from pandas.core.reshape.merge import merge
#    7283
# -> 7284         return merge(
#    7285             self,
#    7286             right,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      71     validate=None,
#      72 ) -> "DataFrame":
# ---> 73     op = _MergeOperation(
#      74         left,
#      75         right,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     625             self.right_join_keys,
#     626             self.join_names,
# --> 627         ) = self._get_merge_keys()
#     628
#     629         # validate the merge keys dtypes. We may need to coerce
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#     994                         right_keys.append(rk)
#     995                     if lk is not None:
# --> 996                         left_keys.append(left._get_label_or_level_values(lk))
#     997                         join_names.append(lk)
#     998                     else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1690             values = self.axes[axis].get_level_values(key)._values
#    1691         else:
# -> 1692             raise KeyError(key)
#    1693
#    1694         # Check for duplicates
#
# KeyError: 'product_id'

# %%
order_list
# Out:
#           order_id  product_id  add_to_cart_order  reordered  \
# 0                2       33120                  1          1
# 1                2       28985                  2          1
# 2                2        9327                  3          0
# 3                2       45918                  4          1
# 4                2       30035                  5          0
# ...            ...         ...                ...        ...
# 32434484   3421083       39678                  6          1
# 32434485   3421083       11352                  7          0
# 32434486   3421083        4600                  8          0
# 32434487   3421083       24852                  9          1
# 32434488   3421083        5020                 10          1
#
#                                                product_name  \
# 0                                        Organic Egg Whites
# 1                                     Michigan Organic Kale
# 2                                             Garlic Powder
# 3                                            Coconut Butter
# 4                                         Natural Sweetener
# ...                                                     ...
# 32434484          Free & Clear Natural Dishwasher Detergent
# 32434485       Organic Mini Sandwich Crackers Peanut Butter
# 32434486                    All Natural French Toast Sticks
# 32434487                                             Banana
# 32434488  Organic  Sweet & Salty Peanut Pretzel Granola ...
#
#                         aisle  department
# 0                        eggs  dairy eggs
# 1            fresh vegetables     produce
# 2           spices seasonings      pantry
# 3               oils vinegars      pantry
# 4          baking ingredients      pantry
# ...                       ...         ...
# 32434484      dish detergents   household
# 32434485             crackers      snacks
# 32434486     frozen breakfast      frozen
# 32434487         fresh fruits     produce
# 32434488  energy granola bars      snacks
#
# [32434489 rows x 7 columns]

# %%
order_list.sample(frac=.05)
# Out:
#           order_id  product_id  add_to_cart_order  reordered  \
# 7483092     789928       17872                  1          1
# 11549800   1219318        6128                 22          1
# 4865537     513576       19505                 10          0
# 29909590   3154717       10831                  7          1
# 25576327   2697337        4605                  4          1
# ...            ...         ...                ...        ...
# 26879492   2834330       35391                 13          0
# 29064054   3065227        3952                 20          1
# 3575878     377795       33754                  5          1
# 20148739   2125174        8138                 13          1
# 14980995   1580745        9159                 12          0
#
#                                                product_name  \
# 7483092                  Total 2% Lowfat Plain Greek Yogurt
# 11549800                      Original Fresh Stack Crackers
# 4865537                                    Sliced Mushrooms
# 29909590                        Yobaby Organic Plain Yogurt
# 25576327                                      Yellow Onions
# ...                                                     ...
# 26879492                                 Sun Dried Tomatoes
# 29064054                            Organic Broccoli Crowns
# 3575878   Total 2% with Strawberry Lowfat Greek Strained...
# 20148739                                 Traditional Hummus
# 14980995                                     Chopped Ginger
#
#                              aisle    department
# 7483092                     yogurt    dairy eggs
# 11549800                  crackers        snacks
# 4865537           fresh vegetables       produce
# 29909590                    yogurt    dairy eggs
# 25576327          fresh vegetables       produce
# ...                            ...           ...
# 26879492  canned jarred vegetables  canned goods
# 29064054          fresh vegetables       produce
# 3575878                     yogurt    dairy eggs
# 20148739      fresh dips tapenades          deli
# 14980995      pickled goods olives        pantry
#
# [1621724 rows x 7 columns]

# %%
order_list['reordered'].value_counts()
# Out:
# 1    19126536
# 0    13307953
# Name: reordered, dtype: int64

# %%
order_list.to_csv("./training_data.csv")
