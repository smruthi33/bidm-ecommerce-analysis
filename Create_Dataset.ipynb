# %%
import pandas as pd

# %%
orders = pd.read_csv("./orders.csv")
orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
products=pd.read_csv("./products.csv")
products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
aisle = pd.read_csv("./aisles.csv")
dept=pd.read_csv("./departments.csv")

# %%
prod_final=products.merge(aisle, on="aisle_id")

# %%
del prod_final["aisle_id"]

# %%
prod_final=prod_final.merge(dept, on="department_id")
del prod_final["department_id"]
prod_final.head()
# Out:
#    product_id                                    product_name          aisle  \
# 0           1                      Chocolate Sandwich Cookies  cookies cakes
# 1          78               Nutter Butter Cookie Bites Go-Pak  cookies cakes
# 2         102                           Danish Butter Cookies  cookies cakes
# 3         172  Gluten Free All Natural Chocolate Chip Cookies  cookies cakes
# 4         285                    Mini Nilla Wafers Munch Pack  cookies cakes
#
#   department
# 0     snacks
# 1     snacks
# 2     snacks
# 3     snacks
# 4     snacks

# %%
orders=orders.loc[orders["eval_set"]!="test"]

# %%
order_prior=pd.read_csv("order_products__prior.csv")
order_train=pd.read_csv("order_products__train.csv")

# %%
orders
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# 3                        7                    29.0
# 4                       15                    28.0
# ...                    ...                     ...
# 3421078                 18                    29.0
# 3421079                 10                    30.0
# 3421080                 12                    18.0
# 3421081                 12                     7.0
# 3421082                 14                    30.0
#
# [3346083 rows x 7 columns]

# %%
order_prior
# Out:
#           order_id  product_id  add_to_cart_order  reordered
# 0                2       33120                  1          1
# 1                2       28985                  2          1
# 2                2        9327                  3          0
# 3                2       45918                  4          1
# 4                2       30035                  5          0
# ...            ...         ...                ...        ...
# 32434484   3421083       39678                  6          1
# 32434485   3421083       11352                  7          0
# 32434486   3421083        4600                  8          0
# 32434487   3421083       24852                  9          1
# 32434488   3421083        5020                 10          1
#
# [32434489 rows x 4 columns]

# %%
order_main_prior=orders.loc[orders["eval_set"]=="prior"]
order_main_prior
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421077   2558525   206209    prior             9          4
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# 3                        7                    29.0
# 4                       15                    28.0
# ...                    ...                     ...
# 3421077                 15                    22.0
# 3421078                 18                    29.0
# 3421079                 10                    30.0
# 3421080                 12                    18.0
# 3421081                 12                     7.0
#
# [3214874 rows x 7 columns]

# %%
order_final_1=order_main_prior.merge(order_prior, on="order_id")
order_final_1.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0

# %%
order_final_1
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2539329        1    prior             1          2
# 2          2539329        1    prior             1          2
# 3          2539329        1    prior             1          2
# 4          2539329        1    prior             1          2
# ...            ...      ...      ...           ...        ...
# 32434484   2977660   206209    prior            13          1
# 32434485   2977660   206209    prior            13          1
# 32434486   2977660   206209    prior            13          1
# 32434487   2977660   206209    prior            13          1
# 32434488   2977660   206209    prior            13          1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         8                     NaN       14084
# 2                         8                     NaN       12427
# 3                         8                     NaN       26088
# 4                         8                     NaN       26405
# ...                     ...                     ...         ...
# 32434484                 12                     7.0       14197
# 32434485                 12                     7.0       38730
# 32434486                 12                     7.0       31477
# 32434487                 12                     7.0        6567
# 32434488                 12                     7.0       22920
#
#           add_to_cart_order  reordered
# 0                         1          0
# 1                         2          0
# 2                         3          0
# 3                         4          0
# 4                         5          0
# ...                     ...        ...
# 32434484                  5          1
# 32434485                  6          0
# 32434486                  7          0
# 32434487                  8          0
# 32434488                  9          0
#
# [32434489 rows x 10 columns]

# %%
order_main_train=orders.loc[orders["eval_set"]=="train"]
order_main_train
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 10        1187899        1    train            11          4
# 25        1492625        2    train            15          1
# 49        2196797        5    train             5          0
# 74         525192        7    train            21          2
# 78         880375        8    train             4          1
# ...           ...      ...      ...           ...        ...
# 3420838   2585586   206199    train            20          2
# 3420862    943915   206200    train            24          6
# 3420924   2371631   206203    train             6          4
# 3420933   1716008   206205    train             4          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 10                       8                    14.0
# 25                      11                    30.0
# 49                      11                     6.0
# 74                      11                     6.0
# 78                      14                    10.0
# ...                    ...                     ...
# 3420838                 16                    30.0
# 3420862                 19                     6.0
# 3420924                 19                    30.0
# 3420933                 16                    10.0
# 3421082                 14                    30.0
#
# [131209 rows x 7 columns]

# %%
order_final_2=order_main_train.merge(order_train, on="order_id")
order_final_2.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   1187899        1    train            11          4                  8
# 1   1187899        1    train            11          4                  8
# 2   1187899        1    train            11          4                  8
# 3   1187899        1    train            11          4                  8
# 4   1187899        1    train            11          4                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                    14.0         196                  1          1
# 1                    14.0       25133                  2          1
# 2                    14.0       38928                  3          1
# 3                    14.0       26405                  4          1
# 4                    14.0       39657                  5          1

# %%
order_final_2
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         1187899        1    train            11          4
# 1         1187899        1    train            11          4
# 2         1187899        1    train            11          4
# 3         1187899        1    train            11          4
# 4         1187899        1    train            11          4
# ...           ...      ...      ...           ...        ...
# 1384612    272231   206209    train            14          6
# 1384613    272231   206209    train            14          6
# 1384614    272231   206209    train            14          6
# 1384615    272231   206209    train            14          6
# 1384616    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order  product_id  \
# 0                        8                    14.0         196
# 1                        8                    14.0       25133
# 2                        8                    14.0       38928
# 3                        8                    14.0       26405
# 4                        8                    14.0       39657
# ...                    ...                     ...         ...
# 1384612                 14                    30.0       40603
# 1384613                 14                    30.0       15655
# 1384614                 14                    30.0       42606
# 1384615                 14                    30.0       37966
# 1384616                 14                    30.0       39216
#
#          add_to_cart_order  reordered
# 0                        1          1
# 1                        2          1
# 2                        3          1
# 3                        4          1
# 4                        5          1
# ...                    ...        ...
# 1384612                  4          0
# 1384613                  5          0
# 1384614                  6          0
# 1384615                  7          0
# 1384616                  8          1
#
# [1384617 rows x 10 columns]

# %%
order_list=order_final_1.append(order_final_2)

# %%
order_list=order_list.merge(prod_final, on="product_id")

# %%
del order_list["product_id"]

# %%
order_list
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2398795        1    prior             2          3
# 2           473747        1    prior             3          3
# 3          2254736        1    prior             4          4
# 4           431534        1    prior             5          4
# ...            ...      ...      ...           ...        ...
# 33819101   3376312   145958    train            34          4
# 33819102   2169250   153763    train            17          6
# 33819103    774603   160879    train            10          5
# 33819104   2271346   169335    train             5          4
# 33819105   3004244   169709    train             8          0
#
#           order_hour_of_day  days_since_prior_order  add_to_cart_order  \
# 0                         8                     NaN                  1
# 1                         7                    15.0                  1
# 2                        12                    21.0                  1
# 3                         7                    29.0                  1
# 4                        15                    28.0                  1
# ...                     ...                     ...                ...
# 33819101                  7                     6.0                  6
# 33819102                 18                    26.0                  9
# 33819103                 10                    11.0                  1
# 33819104                 13                    30.0                 15
# 33819105                 18                    14.0                 25
#
#           reordered                                       product_name  \
# 0                 0                                               Soda
# 1                 1                                               Soda
# 2                 1                                               Soda
# 3                 1                                               Soda
# 4                 1                                               Soda
# ...             ...                                                ...
# 33819101          0                            Water With Electrolytes
# 33819102          0                   Wasabi Cheddar Spreadable Cheese
# 33819103          0                                 Chocolate Go Bites
# 33819104          0  Ultra Sun Blossom Liquid 90 loads Fabric Enhan...
# 33819105          0                               Sweetart Jelly Beans
#
#                     aisle  department
# 0             soft drinks   beverages
# 1             soft drinks   beverages
# 2             soft drinks   beverages
# 3             soft drinks   beverages
# 4             soft drinks   beverages
# ...                   ...         ...
# 33819101          missing     missing
# 33819102  packaged cheese  dairy eggs
# 33819103    cookies cakes      snacks
# 33819104          laundry   household
# 33819105          missing     missing
#
# [33819106 rows x 12 columns]

# %%
order_list.to_csv("./train_dataset.csv")
